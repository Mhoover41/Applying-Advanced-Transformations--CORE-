# %% [markdown]
# # Part 1:  Clean the files and combine them into one final DataFrame.
#
# This dataframe should have the following columns:
# - Hero (Just the name of the Hero)
# - Publisher
# - Gender
# - Eye color
# - Race
# - Hair color
# - Height (numeric)
# - Skin color
# - Alignment
# - Weight (numeric)
# - Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
#     - Agility
#     - Flight
#     - Superspeed
#     - etc.
#
# Hint: There is a space in "100 kg" or "52.5 cm"

# %% [markdown]
# ## Import Libraries

# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %% [markdown]
# ## Read in the Data

# %%
df = pd.read_csv('Data/superhero_info.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df2 = pd.read_csv('Data/superhero_powers.csv')
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# ## Split Hero|Publisher into two columns

# %%
# Exploring existing format with a few examples
df['Hero|Publisher'].head(2)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# Name: Hero|Publisher, dtype: object

# %%
## adding expand=True
df['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
df[['Hero','Publisher']] = df['Hero|Publisher'].str.split('|',expand=True)
df.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
## drop the original column 
df = df.drop(columns=['Hero|Publisher'])
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %% [markdown]
# ## Split Measurements Column

# %%
df['Measurements'].head(3)
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# Name: Measurements, dtype: object

# %%
#check data type
type(df['Measurements'][0])
# Out:
# str

# %%
# replacing single quotes with double quotes
df['Measurements'] = df['Measurements'].str.replace("'", '"')
df['Measurements']
# Out:
# 0      {"Height": "203.0 cm", "Weight": "441.0 kg"}
# 1       {"Height": "191.0 cm", "Weight": "65.0 kg"}
# 2       {"Height": "185.0 cm", "Weight": "90.0 kg"}
# 3      {"Height": "203.0 cm", "Weight": "441.0 kg"}
# 4      {"Height": "193.0 cm", "Weight": "122.0 kg"}
#                            ...
# 458     {"Height": "183.0 cm", "Weight": "83.0 kg"}
# 459     {"Height": "165.0 cm", "Weight": "52.0 kg"}
# 460      {"Height": "66.0 cm", "Weight": "17.0 kg"}
# 461     {"Height": "170.0 cm", "Weight": "57.0 kg"}
# 462     {"Height": "185.0 cm", "Weight": "81.0 kg"}
# Name: Measurements, Length: 463, dtype: object

# %% [markdown]
# - Now that we have double quotes inside our string, we can use json.loads

# %%
df['Measurements'] = df['Measurements'].apply(json.loads)
df['Measurements'].head(3)
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# Name: Measurements, dtype: object

# %%
#check data type
type(df['Measurements'][0])
# Out:
# dict

# %%
#Convert into two different columns 
height_weight = df['Measurements'].apply(pd.Series)
height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# concat height_weight with original dataframe
df = pd.concat((df, height_weight), axis = 1)
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
# Drop the original column now
df = df.drop(columns=['Measurements'])

# %%
df.head(3)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
# 2   Male        Ungaran      good    No Hair      blue        red    Abin Sur
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# 2          DC Comics  185.0 cm   90.0 kg

# %% [markdown]
# ## Convert Height and Weight to Numeric

# %%
# Check current data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %% [markdown]
# ### Height Column

# %%
df.rename(columns={'Height': 'Height (cm)', 'Weight': 'Weight (kg)'},
              inplace=True)
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height (cm) Weight (kg)
# 0      Marvel Comics    203.0 cm    441.0 kg
# 1  Dark Horse Comics    191.0 cm     65.0 kg

# %%
type(df['Height (cm)'][0])
# Out:
# str

# %%
# remove empty space and 'cm' from 'Height (cm)'

to_replace = [' ', 'cm']

for char in to_replace:
    df['Height (cm)'] = df['Height (cm)'].str.replace(char, '', regex=False)
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height (cm) Weight (kg)
# 0      Marvel Comics       203.0    441.0 kg
# 1  Dark Horse Comics       191.0     65.0 kg

# %%
#Change data type to float 
df['Height (cm)'] = df['Height (cm)'].astype('float')
type(df['Height (cm)'][0])
# Out:
# numpy.float64

# %%
#Check data type again
type(df['Height (cm)'][0])
# Out:
# numpy.float64

# %% [markdown]
# ### Weight Column

# %%
#Check data type 
type(df['Weight (kg)'][0])
# Out:
# str

# %%
# remove empty space and 'cm' from 'Height (cm)'

to_replace = [' ', 'kg']

for char in to_replace:
    df['Weight (kg)'] = df['Weight (kg)'].str.replace(char, '', regex=False)
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher  Height (cm) Weight (kg)
# 0      Marvel Comics        203.0       441.0
# 1  Dark Horse Comics        191.0        65.0

# %%
#Change data type to float 
df['Weight (kg)'] = df['Weight (kg)'].astype('float')
type(df['Weight (kg)'][0])
# Out:
# numpy.float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       463 non-null    object
#  1   Race         463 non-null    object
#  2   Alignment    463 non-null    object
#  3   Hair color   463 non-null    object
#  4   Eye color    463 non-null    object
#  5   Skin color   463 non-null    object
#  6   Hero         463 non-null    object
#  7   Publisher    463 non-null    object
#  8   Height (cm)  463 non-null    float64
#  9   Weight (kg)  463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %% [markdown]
# ## One Hot Encode Powers Column

# %%
#Checking data type
print(type(df2['Powers'][0]))
df2['Powers'][0]
# Out:
# <class 'str'>
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
#Convert Powers column to list
df2['Powers_Split'] = df2['Powers'].str.split(',')

# %%
#checking data type 
print(type(df2['Powers_Split'][0]))
df2['Powers_Split']
# Out:
# <class 'list'>
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: Powers_Split, Length: 667, dtype: object

# %%
df2['Powers_Split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# [Marksmanship]                                                                                                                                                                                                                                                                          4
# [Teleportation]                                                                                                                                                                                                                                                                         4
#                                                                                                                                                                                                                                                                                        ..
# [Accelerated Healing, Flight, Telepathy, Energy Blasts, Teleportation, Telekinesis, Astral Projection, Psionic Powers, Mind Blast, Regeneration, Illusions, Resurrection]                                                                                                               1
# [Flight, Telepathy, Animal Oriented Powers, Gliding]                                                                                                                                                                                                                                    1
# [Accelerated Healing, Durability, Energy Absorption, Flight, Super Strength, Telepathy, Energy Blasts, Size Changing, Super Speed, Darkforce Manipulation, Enhanced Senses, Phasing, Invulnerability, Self-Sustenance, Gravity Control, Energy Manipulation, Time Travel, Illusions]    1
# [Agility, Accelerated Healing, Super Strength, Super Speed, Animal Oriented Powers, Enhanced Senses, Jump, Reflexes, Natural Weapons]                                                                                                                                                   1
# [Super Speed, Intangibility, Time Travel, Time Manipulation]                                                                                                                                                                                                                            1
# Name: Powers_Split, Length: 608, dtype: int64

# %%
## exploding the column of lists
exploded = df2.explode('Powers_Split')
exploded.head(5)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_Split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %% [markdown]
# Now we will take the .unique values from this exploded column as our list of columns to create from our original non-exploded dataframe.
#
# Importantly, we do not want to save NaN to our list, so we can use .dropna() right before our .unique()

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['Powers_Split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %% [markdown]
# ### Using a For Loop and .str.contains to create the new columns

# %%
for col in cols_to_make:
    df2[col] = df2['Powers'].str.contains(col)
df2.head()
# Out:
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_29360\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# 0     True         True                False       False      False  ...
# 1     True        False                 True        True       True  ...
# 2     True        False                 True        True       True  ...
# 3    False        False                False       False      False  ...
# 4     True         True                 True       False      False  ...
#
#    Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 0            False        False       False              False       False
# 1            False        False       False              False       False
# 2            False        False       False              False       False
# 3            False        False       False              False       False
# 4            False        False       False              False       False
#
#    Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0       False          False               False    False           False
# 1       False          False               False    False           False
# 2       False          False               False    False           False
# 3       False          False               False    False           False
# 4       False          False               False    False           False
#
# [5 rows x 170 columns]

# %% [markdown]
# Let's drop the original Powers column and our Powers_Split column now that we have confirmed our new columns were created correctly.

# %%
# drop Powers and Powers_Split columns
df2.drop(columns=['Powers', 'Powers_Split'], inplace=True)
df2.head(3)
# Out:
#    hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0     3-D Man     True            True     True         True
# 1      A-Bomb    False            True     True        False
# 2  Abe Sapien     True            True     True        False
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# 1  ...            False        False       False              False
# 2  ...            False        False       False              False
#
#    Nova Force  Odin Force  Phoenix Force  Intuitive aptitude  Melting  \
# 0       False       False          False               False    False
# 1       False       False          False               False    False
# 2       False       False          False               False    False
#
#    Changing Armor
# 0           False
# 1           False
# 2           False
#
# [3 rows x 168 columns]

# %% [markdown]
# ## Combining both Dataframes into one

# %%
df_combined = pd.merge(df, df2, left_on='Hero', right_on='hero_names')
df_combined.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher  Height (cm)  Weight (kg)  ... Weather Control  \
# 0      Marvel Comics        203.0        441.0  ...           False
# 1  Dark Horse Comics        191.0         65.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0        False       False              False       False       False
# 1        False       False              False       False       False
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0          False               False    False           False
# 1          False               False    False           False
#
# [2 rows x 178 columns]

# %%
print(df_combined.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Data columns (total 178 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    Gender                        object
#  1    Race                          object
#  2    Alignment                     object
#  3    Hair color                    object
#  4    Eye color                     object
#  5    Skin color                    object
#  6    Hero                          object
#  7    Publisher                     object
#  8    Height (cm)                   float64
#  9    Weight (kg)                   float64
#  10   hero_names                    object
#  11   Agility                       bool
#  12   Super Strength                bool
#  13   Stamina                       bool
#  14   Super Speed                   bool
#  15   Accelerated Healing           bool
#  16   Durability                    bool
#  17   Longevity                     bool
#  18   Camouflage                    bool
#  19   Self-Sustenance               bool
#  20   Cold Resistance               bool
#  21   Underwater breathing          bool
#  22   Marksmanship                  bool
#  23   Weapons Master                bool
#  24   Intelligence                  bool
#  25   Telepathy                     bool
#  26   Immortality                   bool
#  27   Reflexes                      bool
#  28   Enhanced Sight                bool
#  29   Sub-Mariner                   bool
#  30   Lantern Power Ring            bool
#  31   Invulnerability               bool
#  32   Animation                     bool
#  33   Super Breath                  bool
#  34   Dimensional Awareness         bool
#  35   Flight                        bool
#  36   Size Changing                 bool
#  37   Teleportation                 bool
#  38   Magic                         bool
#  39   Dimensional Travel            bool
#  40   Molecular Manipulation        bool
#  41   Energy Manipulation           bool
#  42   Power Cosmic                  bool
#  43   Energy Absorption             bool
#  44   Elemental Transmogrification  bool
#  45   Fire Resistance               bool
#  46   Natural Armor                 bool
#  47   Heat Resistance               bool
#  48   Matter Absorption             bool
#  49   Regeneration                  bool
#  50   Stealth                       bool
#  51   Power Suit                    bool
#  52   Energy Blasts                 bool
#  53   Energy Beams                  bool
#  54   Heat Generation               bool
#  55   Danger Sense                  bool
#  56   Phasing                       bool
#  57   Force Fields                  bool
#  58   Hypnokinesis                  bool
#  59   Invisibility                  bool
#  60   Enhanced Senses               bool
#  61   Jump                          bool
#  62   Shapeshifting                 bool
#  63   Elasticity                    bool
#  64   Substance Secretion           bool
#  65   Enhanced Hearing              bool
#  66   Adaptation                    bool
#  67   Gliding                       bool
#  68   Natural Weapons               bool
#  69   Wallcrawling                  bool
#  70   Vision - Thermal              bool
#  71   Power Augmentation            bool
#  72   Cryokinesis                   bool
#  73   Duplication                   bool
#  74   Weapon-based Powers           bool
#  75   Fire Control                  bool
#  76   Enhanced Memory               bool
#  77   Energy Constructs             bool
#  78   Power Absorption              bool
#  79   Time Travel                   bool
#  80   Enhanced Smell                bool
#  81   Water Control                 bool
#  82   Vision - Telescopic           bool
#  83   Magnetism                     bool
#  84   Vision - Microscopic          bool
#  85   Vision - Night                bool
#  86   Vision - Heat                 bool
#  87   Vision - X-Ray                bool
#  88   Psionic Powers                bool
#  89   Toxin and Disease Resistance  bool
#  90   Animal Attributes             bool
#  91   Animal Oriented Powers        bool
#  92   Toxin and Disease Control     bool
#  93   Empathy                       bool
#  94   Animal Control                bool
#  95   Darkforce Manipulation        bool
#  96   Time Manipulation             bool
#  97   Reality Warping               bool
#  98   Web Creation                  bool
#  99   Symbiote Costume              bool
#  100  Telekinesis                   bool
#  101  Levitation                    bool
#  102  Biokinesis                    bool
#  103  Sonar                         bool
#  104  Enhanced Touch                bool
#  105  Seismic Power                 bool
#  106  Energy Armor                  bool
#  107  Omnilingualism                bool
#  108  Radiation Immunity            bool
#  109  Density Control               bool
#  110  Light Control                 bool
#  111  Illumination                  bool
#  112  Molecular Combustion          bool
#  113  Astral Travel                 bool
#  114  Precognition                  bool
#  115  Intangibility                 bool
#  116  Illusions                     bool
#  117  Audio Control                 bool
#  118  Sonic Scream                  bool
#  119  Peak Human Condition          bool
#  120  Vision - Infrared             bool
#  121  Dexterity                     bool
#  122  Omnitrix                      bool
#  123  Omnipotent                    bool
#  124  Possession                    bool
#  125  Energy Resistance             bool
#  126  Vision - Cryo                 bool
#  127  Mind Control                  bool
#  128  Mind Blast                    bool
#  129  Clairvoyance                  bool
#  130  Probability Manipulation      bool
#  131  Death Touch                   bool
#  132  Electrokinesis                bool
#  133  Gravity Control               bool
#  134  Technopath/Cyberpath          bool
#  135  Radar Sense                   bool
#  136  Astral Projection             bool
#  137  Cloaking                      bool
#  138  Telepathy Resistance          bool
#  139  Mind Control Resistance       bool
#  140  Hyperkinesis                  bool
#  141  Spatial Awareness             bool
#  142  Radiation Control             bool
#  143  Radiation Absorption          bool
#  144  Magic Resistance              bool
#  145  Element Control               bool
#  146  Plant Control                 bool
#  147  Terrakinesis                  bool
#  148  Power Sense                   bool
#  149  Wind Control                  bool
#  150  Qwardian Power Ring           bool
#  151  Echolocation                  bool
#  152  Resurrection                  bool
#  153  The Force                     bool
#  154  Summoning                     bool
#  155  Banish                        bool
#  156  Molecular Dissipation         bool
#  157  Electrical Transport          bool
#  158  Speed Force                   bool
#  159  Grim Reaping                  bool
#  160  Portal Creation               bool
#  161  Vitakinesis                   bool
#  162  Projection                    bool
#  163  Insanity                      bool
#  164  Photographic Reflexes         bool
#  165  Anti-Gravity                  bool
#  166  Thirstokinesis                bool
#  167  Power Nullifier               bool
#  168  Weather Control               bool
#  169  Omnipresent                   bool
#  170  Omniscient                    bool
#  171  Hair Manipulation             bool
#  172  Nova Force                    bool
#  173  Odin Force                    bool
#  174  Phoenix Force                 bool
#  175  Intuitive aptitude            bool
#  176  Melting                       bool
#  177  Changing Armor                bool
# dtypes: bool(167), float64(2), object(9)
# memory usage: 118.9+ KB
# None

# %%
#drop hero_names since it's a duplicate column of "Hero"
df_combined= df_combined.drop(columns=['hero_names'])

# %%
print(df_combined.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    Gender                        object
#  1    Race                          object
#  2    Alignment                     object
#  3    Hair color                    object
#  4    Eye color                     object
#  5    Skin color                    object
#  6    Hero                          object
#  7    Publisher                     object
#  8    Height (cm)                   float64
#  9    Weight (kg)                   float64
#  10   Agility                       bool
#  11   Super Strength                bool
#  12   Stamina                       bool
#  13   Super Speed                   bool
#  14   Accelerated Healing           bool
#  15   Durability                    bool
#  16   Longevity                     bool
#  17   Camouflage                    bool
#  18   Self-Sustenance               bool
#  19   Cold Resistance               bool
#  20   Underwater breathing          bool
#  21   Marksmanship                  bool
#  22   Weapons Master                bool
#  23   Intelligence                  bool
#  24   Telepathy                     bool
#  25   Immortality                   bool
#  26   Reflexes                      bool
#  27   Enhanced Sight                bool
#  28   Sub-Mariner                   bool
#  29   Lantern Power Ring            bool
#  30   Invulnerability               bool
#  31   Animation                     bool
#  32   Super Breath                  bool
#  33   Dimensional Awareness         bool
#  34   Flight                        bool
#  35   Size Changing                 bool
#  36   Teleportation                 bool
#  37   Magic                         bool
#  38   Dimensional Travel            bool
#  39   Molecular Manipulation        bool
#  40   Energy Manipulation           bool
#  41   Power Cosmic                  bool
#  42   Energy Absorption             bool
#  43   Elemental Transmogrification  bool
#  44   Fire Resistance               bool
#  45   Natural Armor                 bool
#  46   Heat Resistance               bool
#  47   Matter Absorption             bool
#  48   Regeneration                  bool
#  49   Stealth                       bool
#  50   Power Suit                    bool
#  51   Energy Blasts                 bool
#  52   Energy Beams                  bool
#  53   Heat Generation               bool
#  54   Danger Sense                  bool
#  55   Phasing                       bool
#  56   Force Fields                  bool
#  57   Hypnokinesis                  bool
#  58   Invisibility                  bool
#  59   Enhanced Senses               bool
#  60   Jump                          bool
#  61   Shapeshifting                 bool
#  62   Elasticity                    bool
#  63   Substance Secretion           bool
#  64   Enhanced Hearing              bool
#  65   Adaptation                    bool
#  66   Gliding                       bool
#  67   Natural Weapons               bool
#  68   Wallcrawling                  bool
#  69   Vision - Thermal              bool
#  70   Power Augmentation            bool
#  71   Cryokinesis                   bool
#  72   Duplication                   bool
#  73   Weapon-based Powers           bool
#  74   Fire Control                  bool
#  75   Enhanced Memory               bool
#  76   Energy Constructs             bool
#  77   Power Absorption              bool
#  78   Time Travel                   bool
#  79   Enhanced Smell                bool
#  80   Water Control                 bool
#  81   Vision - Telescopic           bool
#  82   Magnetism                     bool
#  83   Vision - Microscopic          bool
#  84   Vision - Night                bool
#  85   Vision - Heat                 bool
#  86   Vision - X-Ray                bool
#  87   Psionic Powers                bool
#  88   Toxin and Disease Resistance  bool
#  89   Animal Attributes             bool
#  90   Animal Oriented Powers        bool
#  91   Toxin and Disease Control     bool
#  92   Empathy                       bool
#  93   Animal Control                bool
#  94   Darkforce Manipulation        bool
#  95   Time Manipulation             bool
#  96   Reality Warping               bool
#  97   Web Creation                  bool
#  98   Symbiote Costume              bool
#  99   Telekinesis                   bool
#  100  Levitation                    bool
#  101  Biokinesis                    bool
#  102  Sonar                         bool
#  103  Enhanced Touch                bool
#  104  Seismic Power                 bool
#  105  Energy Armor                  bool
#  106  Omnilingualism                bool
#  107  Radiation Immunity            bool
#  108  Density Control               bool
#  109  Light Control                 bool
#  110  Illumination                  bool
#  111  Molecular Combustion          bool
#  112  Astral Travel                 bool
#  113  Precognition                  bool
#  114  Intangibility                 bool
#  115  Illusions                     bool
#  116  Audio Control                 bool
#  117  Sonic Scream                  bool
#  118  Peak Human Condition          bool
#  119  Vision - Infrared             bool
#  120  Dexterity                     bool
#  121  Omnitrix                      bool
#  122  Omnipotent                    bool
#  123  Possession                    bool
#  124  Energy Resistance             bool
#  125  Vision - Cryo                 bool
#  126  Mind Control                  bool
#  127  Mind Blast                    bool
#  128  Clairvoyance                  bool
#  129  Probability Manipulation      bool
#  130  Death Touch                   bool
#  131  Electrokinesis                bool
#  132  Gravity Control               bool
#  133  Technopath/Cyberpath          bool
#  134  Radar Sense                   bool
#  135  Astral Projection             bool
#  136  Cloaking                      bool
#  137  Telepathy Resistance          bool
#  138  Mind Control Resistance       bool
#  139  Hyperkinesis                  bool
#  140  Spatial Awareness             bool
#  141  Radiation Control             bool
#  142  Radiation Absorption          bool
#  143  Magic Resistance              bool
#  144  Element Control               bool
#  145  Plant Control                 bool
#  146  Terrakinesis                  bool
#  147  Power Sense                   bool
#  148  Wind Control                  bool
#  149  Qwardian Power Ring           bool
#  150  Echolocation                  bool
#  151  Resurrection                  bool
#  152  The Force                     bool
#  153  Summoning                     bool
#  154  Banish                        bool
#  155  Molecular Dissipation         bool
#  156  Electrical Transport          bool
#  157  Speed Force                   bool
#  158  Grim Reaping                  bool
#  159  Portal Creation               bool
#  160  Vitakinesis                   bool
#  161  Projection                    bool
#  162  Insanity                      bool
#  163  Photographic Reflexes         bool
#  164  Anti-Gravity                  bool
#  165  Thirstokinesis                bool
#  166  Power Nullifier               bool
#  167  Weather Control               bool
#  168  Omnipresent                   bool
#  169  Omniscient                    bool
#  170  Hair Manipulation             bool
#  171  Nova Force                    bool
#  172  Odin Force                    bool
#  173  Phoenix Force                 bool
#  174  Intuitive aptitude            bool
#  175  Melting                       bool
#  176  Changing Armor                bool
# dtypes: bool(167), float64(2), object(8)
# memory usage: 131.5+ KB
# None

# %% [markdown]
# # Part 2: Use your combined DataFrame to answer the following questions.
#
# ## 1. Compare the average weight of super powers who have Super Speed to those who do not.

# %%
np.where(cols_to_make == 'Super Speed')
# Out:
# (array([3], dtype=int64),)

# %%
heroes_speed = df_combined['Super Speed'] == True
df_speed = df_combined[heroes_speed]
df_speed
# Out:
#      Gender               Race Alignment Hair color Eye color Skin color  \
# 3      Male  Human / Radiation       bad    No Hair     green    Unknown
# 5      Male              Human      good      Blond      blue    Unknown
# 8      Male            Unknown       bad      White      blue    Unknown
# 9      Male             Cyborg       bad      Black     brown    Unknown
# 10     Male            Unknown      good      Blond      blue    Unknown
# ..      ...                ...       ...        ...       ...        ...
# 453  Female           Demi-God      good      Blond      blue    Unknown
# 454    Male            Unknown      good      Black       red    Unknown
# 455  Female             Amazon      good      Black      blue    Unknown
# 460    Male     Yoda's species      good      White     brown      green
# 462    Male            Unknown       bad      Brown       red    Unknown
#
#              Hero      Publisher  Height (cm)  Weight (kg)  ...  \
# 3     Abomination  Marvel Comics        203.0        441.0  ...
# 5    Adam Strange      DC Comics        185.0         88.0  ...
# 8      Air-Walker  Marvel Comics        188.0        108.0  ...
# 9            Ajax  Marvel Comics        193.0         90.0  ...
# 10     Alan Scott      DC Comics        180.0         90.0  ...
# ..            ...            ...          ...          ...  ...
# 453   Wonder Girl      DC Comics        165.0         51.0  ...
# 454    Wonder Man  Marvel Comics        188.0        171.0  ...
# 455  Wonder Woman      DC Comics        183.0         74.0  ...
# 460          Yoda   George Lucas         66.0         17.0  ...
# 462          Zoom      DC Comics        185.0         81.0  ...
#
#      Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 3              False        False       False              False       False
# 5              False        False       False              False       False
# 8              False        False       False              False       False
# 9              False        False       False              False       False
# 10             False        False       False              False       False
# ..               ...          ...         ...                ...         ...
# 453            False        False       False              False       False
# 454            False        False       False              False       False
# 455            False        False       False              False       False
# 460            False        False       False              False       False
# 462            False        False       False              False       False
#
#      Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 3         False          False               False    False           False
# 5         False          False               False    False           False
# 8         False          False               False    False           False
# 9         False          False               False    False           False
# 10        False          False               False    False           False
# ..          ...            ...                 ...      ...             ...
# 453       False          False               False    False           False
# 454       False          False               False    False           False
# 455       False          False               False    False           False
# 460       False          False               False    False           False
# 462       False          False               False    False           False
#
# [198 rows x 177 columns]

# %%
df_not_speed = df_combined[~heroes_speed]
df_not_speed
# Out:
#      Gender            Race Alignment        Hair color Eye color Skin color  \
# 0      Male           Human      good           No Hair    yellow    Unknown
# 1      Male   Icthyo Sapien      good           No Hair      blue       blue
# 2      Male         Ungaran      good           No Hair      blue        red
# 4      Male           Human       bad           No Hair      blue    Unknown
# 6      Male           Human      good             Brown     brown    Unknown
# ..      ...             ...       ...               ...       ...        ...
# 456  Female  Mutant / Clone      good             Black     green    Unknown
# 457    Male         Unknown      good             Brown      blue    Unknown
# 458    Male           Human      good             Blond      blue    Unknown
# 459  Female           Human      good  Strawberry Blond      blue    Unknown
# 461  Female           Human      good             Black      blue    Unknown
#
#                 Hero          Publisher  Height (cm)  Weight (kg)  ...  \
# 0             A-Bomb      Marvel Comics        203.0        441.0  ...
# 1         Abe Sapien  Dark Horse Comics        191.0         65.0  ...
# 2           Abin Sur          DC Comics        185.0         90.0  ...
# 4      Absorbing Man      Marvel Comics        193.0        122.0  ...
# 6          Agent Bob      Marvel Comics        178.0         81.0  ...
# ..               ...                ...          ...          ...  ...
# 456             X-23      Marvel Comics        155.0         50.0  ...
# 457            X-Man      Marvel Comics        175.0         61.0  ...
# 458     Yellowjacket      Marvel Comics        183.0         83.0  ...
# 459  Yellowjacket II      Marvel Comics        165.0         52.0  ...
# 461          Zatanna          DC Comics        170.0         57.0  ...
#
#      Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 0              False        False       False              False       False
# 1              False        False       False              False       False
# 2              False        False       False              False       False
# 4              False        False       False              False       False
# 6              False        False       False              False       False
# ..               ...          ...         ...                ...         ...
# 456            False        False       False              False       False
# 457            False        False       False              False       False
# 458            False        False       False              False       False
# 459            False        False       False              False       False
# 461             True        False       False              False       False
#
#      Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0         False          False               False    False           False
# 1         False          False               False    False           False
# 2         False          False               False    False           False
# 4         False          False               False    False           False
# 6         False          False               False    False           False
# ..          ...            ...                 ...      ...             ...
# 456       False          False               False    False           False
# 457       False          False               False    False           False
# 458       False          False               False    False           False
# 459       False          False               False    False           False
# 461       False          False               False    False           False
#
# [265 rows x 177 columns]

# %%
avg_speed_weight = df_speed['Weight (kg)'].mean().round(2)
avg_not_speed_weight = df_not_speed['Weight (kg)'].mean().round(2)
print(f'The average weight (kg) for Super Heroes that have "Super Speed" is {avg_speed_weight}')
print(f'The average weight (kg) for Super Heroes that do not have "Super Speed" is {avg_not_speed_weight}')
# Out:
# The average weight (kg) for Super Heroes that have "Super Speed" is 129.4
# The average weight (kg) for Super Heroes that do not have "Super Speed" is 101.77

# %% [markdown]
# ## 2. What is the average height of heroes for each publisher?

# %%
publisher_height = df.groupby('Publisher')['Height (cm)'].mean().sort_values(ascending=False)
publisher_height
# Out:
# Publisher
# Image Comics         211.000000
# Marvel Comics        191.546128
# DC Comics            181.923913
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Dark Horse Comics    176.909091
# Shueisha             171.500000
# George Lucas         159.600000
# Name: Height (cm), dtype: float64
